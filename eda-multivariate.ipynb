# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./Data/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                 society      sector       price  \
# 0          flat      emaar palm gardens   sector 83   1.8 Crore
# 1          flat  breez global hill view  sohna road   29.99 Lac
# 2          flat      ambience creacions   sector 22  4.78 Crore
# 3          flat     aipl zen residences  sector 70a  1.25 Crore
# 4          flat              sare homes   sector 92  1.18 Crore
#
#    price_per_sqft                                       areaWithType  bedRoom  \
# 0          9473.0             Super Built up area 1900(176.52 sq.m.)        3
# 1          5403.0  Super Built up area 655(60.85 sq.m.)Carpet are...        2
# 2         15469.0  Super Built up area 3090(287.07 sq.m.)Built Up...        3
# 3          9904.0                   Carpet area: 1262 (117.24 sq.m.)        2
# 4          5207.0                   Carpet area: 2266 (210.52 sq.m.)        4
#
#    bathroom balcony  floorNum      facing    agePossession  area  \
# 0         3      3+       9.0       South  1 to 5 Year Old   NaN
# 1         2       2       6.0  North-East  0 to 1 Year Old   NaN
# 2         4       3       7.0        West  1 to 5 Year Old   NaN
# 3         2       3      19.0         NaN        undefined   NaN
# 4         4       3       8.0       North  1 to 5 Year Old   NaN
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1900.0            NaN          NaN           0             0
# 1                655.0            NaN        555.0           0             0
# 2               3090.0         2500.0       2250.0           0             1
# 3                  NaN            NaN       1262.0           0             0
# 4                  NaN            NaN       2266.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            55
# 1           0           0       0                0           109
# 2           0           0       1                2           111
# 3           0           0       0                0             0
# 4           0           0       0                0           108

# %%
sns.barplot(data=df, x='property_type', y='price', estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median, orient='v')
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
sns.barplot(data=df, x='property_type', y='price', estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
print(df['price'].dtype)
# Out:
# float64

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
import pandas as pd

# example column
# df['price'] = ["1.8 Crore", "29.99 Lac", "4.78 Crore", "1.25 Crore", "1.18 Crore"]

def convert_to_crore(x):
    x = str(x).lower().strip()
    
    if 'crore' in x:
        value = float(x.replace('crore', '').strip())
        return value
    
    elif 'lac' in x:
        value = float(x.replace('lac', '').strip())
        return value * 0.01  # convert lakh → crore

    return None  # in case of unexpected format

df['price_crore'] = df['price'].apply(convert_to_crore)

# %%
df['price'] = df['price_crore'].astype(float)

# %%
df[df['property_type']=="house"]
# Out:
#      property_type                              society      sector  price  \
# 11           house                                  NaN   sector 12    NaN
# 12           house                                  NaN   sector 55    NaN
# 14           house                                  NaN    sector 6    NaN
# 21           house                                  NaN   sector 25    NaN
# 24           house                                  NaN   sector 12    NaN
# ...            ...                                  ...         ...    ...
# 3777         house                        rwa sector 46   sector 46    NaN
# 3785         house                    anant raj estates  sector 63a    NaN
# 3792         house          ashok vihar phase 3 gurgaon    sector 5    NaN
# 3794         house  international city by sobha phase 2  sector 109    NaN
# 3809         house                        sector 38 rwa   sector 38    NaN
#
#       price_per_sqft                                       areaWithType  \
# 11            6034.0                       Plot area 1160(107.77 sq.m.)
# 12           27741.0                        Plot area 300(250.84 sq.m.)
# 14           13889.0                          Plot area 40(33.45 sq.m.)
# 21           38760.0                        Plot area 215(179.77 sq.m.)
# 24           14184.0  Plot area 846(78.6 sq.m.)Built Up area: 846 sq...
# ...              ...                                                ...
# 3777         21605.0                         Plot area 180(150.5 sq.m.)
# 3785         27139.0                        Plot area 348(290.97 sq.m.)
# 3792          8878.0                        Plot area 1070(99.41 sq.m.)
# 3794         12593.0                        Plot area 600(501.68 sq.m.)
# 3809         28782.0  Plot area 166(138.8 sq.m.)Built Up area: 165 s...
#
#       bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 11          3         3       0       1.0  North-East     1 to 5 Year Old
# 12         12        12      3+       4.0  South-East     1 to 5 Year Old
# 14          5         3       3       3.0         NaN        10+ Year Old
# 21          9         9       3       4.0        East     1 to 5 Year Old
# 24          4         4       2       2.0       North     1 to 5 Year Old
# ...       ...       ...     ...       ...         ...                 ...
# 3777        4         4       2       2.0  South-East     1 to 5 Year Old
# 3785        6         6      3+       3.0        East  Under Construction
# 3792        4         3       2       1.0        East        10+ Year Old
# 3794        4         5       3       2.0  North-West     1 to 5 Year Old
# 3809        9         9      3+       3.0        East     1 to 5 Year Old
#
#         area  super_built_up_area  built_up_area  carpet_area  study room  \
# 11    1160.0                  NaN         1160.0          NaN           0
# 12    2700.0                  NaN          300.0          NaN           1
# 14     360.0                  NaN           40.0          NaN           0
# 21    1961.0                  NaN          215.0          NaN           1
# 24     846.0                  NaN          846.0          NaN           0
# ...      ...                  ...            ...          ...         ...
# 3777  1620.0                  NaN          180.0          NaN           0
# 3785  3132.0                  NaN          348.0          NaN           0
# 3792  1070.0                  NaN         1070.0          NaN           0
# 3794  5400.0                  NaN          600.0          NaN           0
# 3809  1494.0                  NaN          165.0        164.0           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 11               0           0           0       0                0
# 12               1           0           1       0                1
# 14               0           0           0       0                0
# 21               0           1           1       0                1
# 24               0           0           1       0                1
# ...            ...         ...         ...     ...              ...
# 3777             0           0           1       0                1
# 3785             0           1           1       0                0
# 3792             0           0           0       0                0
# 3794             1           0           0       0                0
# 3809             0           0           1       1                1
#
#       luxury_score  price_crore
# 11              23          NaN
# 12              49          NaN
# 14               0          NaN
# 21              84          NaN
# 24               7          NaN
# ...            ...          ...
# 3777            30          NaN
# 3785            29          NaN
# 3792             8          NaN
# 3794            49          NaN
# 3809            41          NaN
#
# [859 rows x 24 columns]

# %%
def convert_to_crore(x):
    x = str(x).lower().strip()
    
    if 'crore' in x:
        return float(x.replace('crore', '').strip())
    
    elif 'lac' in x:
        return float(x.replace('lac', '').strip()) * 0.01
    
    return None


# apply only for flats
mask = df['property_type'] == 'flat'

df.loc[mask, 'price'] = df.loc[mask, 'price'].apply(convert_to_crore)
# Out:
# C:\Users\kael7\AppData\Local\Temp\ipykernel_25588\3245704903.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[None None None ... None None None]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, 'price'] = df.loc[mask, 'price'].apply(convert_to_crore)

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

ax = sns.barplot(
    x='property_type',
    y='price',
    data=df,
    estimator=np.median
)

# ensure normal axis
ax.set_ylim(bottom=0)

plt.show()

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.boxplot(x=df['property_type'], y=df['price'])
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)
#     697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:4485, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4483     positions = list(range(1, N + 1))
#    4484 elif len(positions) != N:
# -> 4485     raise ValueError(datashape_message.format("positions"))
#    4487 positions = np.array(positions)
#    4488 if len(positions) > 0 and not all(isinstance(p, Real) for p in positions):
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector price  \
# 74           house         bhim nagar, sector 6   sector 6  0.85
# 221          house       unitech deerwood chase  sector 50  8.45
# 225          house          huda plot sector 38  sector 38   4.3
# 366           flat           ambience caitriona  sector 24  14.0
# 369          house     unitech uniworld resorts  sector 33  10.0
# 651          house       emaar the palm springs  sector 54  24.0
# 681          house            vatika india next  sector 82   7.0
# 768          house                          NaN  sector 12   3.5
# 835          house                    rk excelo  sector 12   0.6
# 1140         house           vipul tatvam villa  sector 48  7.25
# 1171         house                   ardee city  sector 52   5.5
# 1214         house                          NaN   sector 4   0.6
# 1227         house     unitech uniworld resorts  sector 33   9.5
# 1242         house       dlf city plots phase 2  sector 25  10.0
# 1280         house                          NaN  sector 38   8.0
# 1679         house                        ansal  sector 43  1.85
# 1757         house                          NaN  sector 23   2.8
# 1802         house                          NaN  sector 55  1.45
# 1814         house               uppal southend  sector 49  6.75
# 1902         house                          NaN  sector 57   8.0
# 2175         house       dlf city plots phase 2  sector 25  10.5
# 2360         house                          NaN  sector 17   3.5
# 2729         house  unitech nirvana birch court  sector 50   7.1
# 2809         house                          NaN  sector 12   6.0
# 2867         house                          NaN  sector 28   4.5
# 2874         house                dlf the grove  sector 54   5.7
# 3295         house                          NaN  sector 54  3.75
# 3312         house         eros rosewood villas  sector 49  2.75
# 3516         house                          NaN  sector 24  10.0
#
#       price_per_sqft   area  \
# 74          126865.0   67.0
# 221         235376.0  359.0
# 225         245398.0  175.0
# 366         200000.0    NaN
# 369         181818.0  550.0
# 651         600000.0  400.0
# 681         194444.0  360.0
# 768         133079.0  263.0
# 835         120000.0   50.0
# 1140        201388.0  360.0
# 1171        183333.0  300.0
# 1214        105263.0   57.0
# 1227        173992.0  546.0
# 1242        400000.0  250.0
# 1280        230547.0  347.0
# 1679        308333.0   60.0
# 1757        161849.0  173.0
# 1802        241666.0   60.0
# 1814        290948.0  232.0
# 1902        266666.0  300.0
# 2175        261194.0  402.0
# 2360        218750.0  160.0
# 2729        283333.0  251.0
# 2809        315789.0  190.0
# 2867        125000.0  360.0
# 2874        211111.0  270.0
# 3295        234375.0  160.0
# 3312        178571.0  154.0
# 3516        229885.0  435.0
#
#                                            areaWithType  super_built_up_area  \
# 74                             Plot area 67(6.22 sq.m.)                  NaN
# 221                          Plot area 359(33.35 sq.m.)                  NaN
# 225   Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 366                    Built Up area: 700 (65.03 sq.m.)                  NaN
# 369                           Plot area 550(51.1 sq.m.)                  NaN
# 651                          Plot area 400(37.16 sq.m.)                  NaN
# 681   Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 768   Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 835   Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 1140                         Plot area 360(33.45 sq.m.)                  NaN
# 1171                         Plot area 300(27.87 sq.m.)                  NaN
# 1214                            Plot area 57(5.3 sq.m.)                  NaN
# 1227                         Plot area 546(50.73 sq.m.)                  NaN
# 1242                         Plot area 250(23.23 sq.m.)                  NaN
# 1280  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 1679                           Plot area 60(5.57 sq.m.)                  NaN
# 1757  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 1802                           Plot area 60(5.57 sq.m.)                  NaN
# 1814                         Plot area 232(21.55 sq.m.)                  NaN
# 1902                         Plot area 300(27.87 sq.m.)                  NaN
# 2175                         Plot area 402(37.35 sq.m.)                  NaN
# 2360                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 2729                          Plot area 240(22.3 sq.m.)                  NaN
# 2809  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2867                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 2874                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 3295                         Plot area 160(14.86 sq.m.)                  NaN
# 3312  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 3516                     Carpet area: 435 (40.41 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 74             67.0          NaN
# 221           359.0          NaN
# 225           145.0          NaN
# 366           700.0          NaN
# 369           550.0          NaN
# 651           400.0          NaN
# 681          3900.0       3743.0
# 768          4800.0       4400.0
# 835            30.0         15.0
# 1140          360.0          NaN
# 1171          300.0          NaN
# 1214           57.0          NaN
# 1227          546.0          NaN
# 1242          250.0          NaN
# 1280          347.0        215.0
# 1679           60.0          NaN
# 1757          160.0        150.0
# 1802           60.0          NaN
# 1814          232.0          NaN
# 1902          300.0          NaN
# 2175          402.0          NaN
# 2360          160.0          NaN
# 2729          240.0          NaN
# 2809            NaN       1600.0
# 2867          360.0          NaN
# 2874          270.0          NaN
# 3295          160.0          NaN
# 3312            NaN       1650.0
# 3516            NaN        435.0

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
df[df['bedRoom'] >= 10]
# Out:
#      property_type society      sector  price  price_per_sqft  \
# 12           house     NaN   sector 55   7.49         27741.0
# 61           house     NaN   sector 43    4.5         39062.0
# 166          house     NaN   sector 40   12.0         38986.0
# 189          house     NaN  sohna road   0.95          8920.0
# 207          house     NaN   sector 11    4.5         25000.0
# ...            ...     ...         ...    ...             ...
# 3267         house     NaN   sector 43    7.5         38760.0
# 3286         house     NaN   sector 46   6.81         36911.0
# 3529         house     NaN   sector 26  14.75         51864.0
# 3599         house     NaN   sector 26   8.49         47167.0
# 3629         house     NaN   sector 57   6.95         38611.0
#
#                      areaWithType  bedRoom  bathroom balcony  floorNum  \
# 12    Plot area 300(250.84 sq.m.)       12        12      3+       4.0
# 61    Plot area 128(107.02 sq.m.)       20        20      3+       4.0
# 166   Plot area 342(285.96 sq.m.)       16        16      3+       4.0
# 189   Plot area 1065(98.94 sq.m.)       10        10      3+       3.0
# 207   Plot area 200(167.23 sq.m.)       16        16      3+       4.0
# ...                           ...      ...       ...     ...       ...
# 3267  Plot area 215(179.77 sq.m.)       12        12      3+       4.0
# 3286  Plot area 205(171.41 sq.m.)       12        14      3+       NaN
# 3529  Plot area 316(264.22 sq.m.)       16        20      3+       4.0
# 3599  Plot area 200(167.23 sq.m.)       12        12      3+       4.0
# 3629  Plot area 192(160.54 sq.m.)       12        12      3+       4.0
#
#           facing    agePossession    area  super_built_up_area  built_up_area  \
# 12    South-East  1 to 5 Year Old  2700.0                  NaN          300.0
# 61          East  1 to 5 Year Old  1152.0                  NaN          128.0
# 166          NaN  0 to 1 Year Old  3078.0                  NaN          342.0
# 189          NaN  0 to 1 Year Old  1065.0                  NaN         1065.0
# 207        South  1 to 5 Year Old  1800.0                  NaN          200.0
# ...          ...              ...     ...                  ...            ...
# 3267        East  0 to 1 Year Old  1935.0                  NaN          215.0
# 3286        East  0 to 1 Year Old  1845.0                  NaN          205.0
# 3529        East  0 to 1 Year Old  2844.0                  NaN          316.0
# 3599       North  1 to 5 Year Old  1800.0                  NaN          200.0
# 3629        East  0 to 1 Year Old  1800.0                  NaN          192.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 12            NaN           1             1           0           1       0
# 61            NaN           0             1           0           0       0
# 166           NaN           1             1           1           1       0
# 189           NaN           0             0           0           0       0
# 207           NaN           0             0           0           0       0
# ...           ...         ...           ...         ...         ...     ...
# 3267          NaN           1             1           1           1       0
# 3286          NaN           0             1           0           0       1
# 3529          NaN           1             1           1           1       0
# 3599          NaN           0             1           0           1       0
# 3629          NaN           0             1           1           0       0
#
#       furnishing_type  luxury_score  price_crore
# 12                  1            49          NaN
# 61                  2            22          NaN
# 166                 1             0          NaN
# 189                 0             0          NaN
# 207                 1            20          NaN
# ...               ...           ...          ...
# 3267                1            72          NaN
# 3286                1            40          NaN
# 3529                1           153          NaN
# 3599                1            42          NaN
# 3629                1            73          NaN
#
# [72 rows x 24 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
# Define the mapping dictionary
age_mapping = {
    '10+ Year Old': 'Old Property',
    '0 to 1 Year Old': 'Moderately Old',
    'Under Construction': 'Under Construction',
    'Within 6 months': 'Undefined',
    # Grouping specific dates into 'New Property' or 'Relatively New'
    # Example: Dates in the past/immediate future vs. distant future
    'Jul 2024': 'New Property', 'Jun 2024': 'New Property', 
    'Aug 2025': 'New Property', 'Jan 2027': 'New Property',
    'Apr 2024': 'Relatively New', 'Aug 2023': 'Relatively New',
    'Dec 2023': 'Relatively New', 'Feb 2024': 'Relatively New'
}

# Apply the mapping to your column
df['agePossession'] = df['agePossession'].map(age_mapping).fillna('Undefined')

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2460, in GroupBy.mean.<locals>.<lambda>(x)
#    2457 else:
#    2458     result = self._cython_agg_general(
#    2459         "mean",
# -> 2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)
#    6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '0.41.71.00.690.450.70.451.341.80.81.70.370.852.153.30.40.60.340.070.550.890.341.64.60.653.351.653.55.51.16' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 plt.figure(figsize=(15,4))
# ----> 2 sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:183, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)
#     181         stacklevel=find_stack_level(),
#     182     )
# --> 183 agged = grouped.agg(aggfunc)
#     185 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     186     agged = agged.dropna(how="all")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2458, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2451     return self._numba_agg_general(
#    2452         grouped_mean,
#    2453         executor.float_dtype_mapping,
#    2454         engine_kwargs,
#    2455         min_periods=0,
#    2456     )
#    2457 else:
# -> 2458     result = self._cython_agg_general(
#    2459         "mean",
#    2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2001, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1998     return result
#    2000 assert alt is not None
# -> 2001 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002 return result
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1947, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1945     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1946     # preserve the kind of exception that raised
# -> 1947     raise type(err)(msg) from err
#    1949 dtype = ser.dtype
#    1950 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
df.groupby('agePossession').mean(numeric_only=True)
# Out:
#                     price_per_sqft   bedRoom  bathroom  floorNum         area  \
# agePossession
# Moderately Old        12080.752000  3.388889  3.503968  7.009940  4920.656250
# New Property          11283.153846  2.615385  2.615385  5.307692  1271.500000
# Old Property          23305.125828  4.029703  3.643564  3.653199  2530.553073
# Relatively New        12213.000000  2.700000  2.700000  6.466667  2808.500000
# Undefined             13380.365335  3.315138  3.420670  7.049671  2816.277580
# Under Construction     8585.500000  2.593407  2.615385  8.977528  2113.500000
#
#                     super_built_up_area  built_up_area  carpet_area  \
# agePossession
# Moderately Old              1776.293000    1325.793233  5387.852386
# New Property                1431.750000    1422.666667  1189.165000
# Old Property                1853.233014     956.438995  1652.500882
# Relatively New              1464.903333    1853.625000  1079.001176
# Undefined                   1966.401442    2079.429071  2070.542150
# Under Construction          1615.495455    1548.680000  2614.660023
#
#                     study room  servant room  store room  pooja room  \
# agePossession
# Moderately Old        0.200397      0.339286    0.075397    0.164683
# New Property          0.153846      0.230769    0.000000    0.000000
# Old Property          0.201320      0.363036    0.155116    0.247525
# Relatively New        0.333333      0.133333    0.066667    0.033333
# Undefined             0.187045      0.374090    0.090611    0.180859
# Under Construction    0.208791      0.153846    0.021978    0.021978
#
#                       others  furnishing_type  luxury_score  price_crore
# agePossession
# Moderately Old      0.123016         0.376984     67.083333     1.481140
# New Property        0.384615         0.076923     34.615385     2.058636
# Old Property        0.158416         0.504950     52.686469     1.881870
# Relatively New      0.033333         0.000000     61.100000     1.686454
# Undefined           0.098981         0.413755     75.238719     1.764009
# Under Construction  0.197802         0.043956     49.164835     1.235876

# %%
sns.boxplot(df['luxury_score'], color='lightgreen')
# Out:
# <Axes: ylabel='luxury_score'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2460, in GroupBy.mean.<locals>.<lambda>(x)
#    2457 else:
#    2458     result = self._cython_agg_general(
#    2459         "mean",
# -> 2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)
#    6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:183, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)
#     181         stacklevel=find_stack_level(),
#     182     )
# --> 183 agged = grouped.agg(aggfunc)
#     185 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     186     agged = agged.dropna(how="all")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2458, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2451     return self._numba_agg_general(
#    2452         grouped_mean,
#    2453         executor.float_dtype_mapping,
#    2454         engine_kwargs,
#    2455         min_periods=0,
#    2456     )
#    2457 else:
# -> 2458     result = self._cython_agg_general(
#    2459         "mean",
#    2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:2001, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1998     return result
#    2000 assert alt is not None
# -> 2001 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002 return result
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1947, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1945     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1946     # preserve the kind of exception that raised
# -> 1947     raise type(err)(msg) from err
#    1949 dtype = ser.dtype
#    1950 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
df['price'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          1.8
# 1       0.2999
# 2         4.78
# 3         1.25
# 4         1.18
#          ...
# 3811       7.0
# 3812       3.6
# 3813      1.08
# 3814    0.9888
# 3815      1.05
# Name: price, Length: 3689, dtype: object>

# %%
pivot = pd.pivot_table(df, index='property_type', columns='furnishing_type', values='price', aggfunc='mean')

# Plot the heatmap
sns.heatmap(pivot, annot=True)
plt.title('Average Price by Property and Furnishing Type')
plt.show()

# %%
# Remove anything that isn't a digit or a decimal point
df['price'] = pd.to_numeric(df['price'].astype(str).str.replace(r'[^\d.]', '', regex=True), errors='coerce')

# Drop any rows where the price couldn't be converted (NaN)
df = df.dropna(subset=['price'])

# %%
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
# Out:
# Text(33.222222222222214, 0.5, 'Sector')

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
import matplotlib.pyplot as plt
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 plt.figure(figsize=(8,8))
# ----> 2 sns.heatmap(df.corr())
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\kael7\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'flat'

# %%
# Convert price to float so aggfunc='mean' can work
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Now run your heatmap code
import seaborn as sns
import matplotlib.pyplot as plt

pivot = pd.pivot_table(
    df, 
    index='property_type', 
    columns='furnishing_type', 
    values='price', 
    aggfunc='mean'
)

sns.heatmap(pivot, annot=True)
plt.show()
# Out:
# C:\Users\kael7\AppData\Local\Temp\ipykernel_30900\169127682.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
print(df[['property_type', 'price']].head())
# Out:
#   property_type   price
# 0          flat  1.8000
# 1          flat  0.2999
# 2          flat  4.7800
# 3          flat  1.2500
# 4          flat  1.1800

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Force the price column to be numeric (removes any 'flat' or other text)
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# 2. Drop rows where price is now NaN (invalid data)
df = df.dropna(subset=['price'])

# 3. Create the pivot table 
# index/columns = CATEGORIES (Text is okay here)
# values = THE NUMBER (Text is NOT okay here)
pivot = pd.pivot_table(
    df, 
    index='property_type', 
    columns='furnishing_type', 
    values='price', 
    aggfunc='mean'
)

# 4. CRITICAL CHECK: Ensure only numbers are in the pivot cells
print("Pivot Table Data Types:")
print(pivot.dtypes)

# 5. Generate Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, cmap='YlGnBu', fmt=".2f")
plt.title('Average Price by Property and Furnishing Type')
plt.show()
# Out:
# C:\Users\kael7\AppData\Local\Temp\ipykernel_30900\3903202370.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = pd.to_numeric(df['price'], errors='coerce')
# Pivot Table Data Types:
# furnishing_type
# 0    float64
# 1    float64
# 2    float64
# dtype: object

# %%
pivot_age = pd.pivot_table(df, index='agePossession', columns='furnishing_type', values='price', aggfunc='mean')
sns.heatmap(pivot_age, annot=True)
plt.show()

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# 2. Calculate correlation ONLY for numeric columns
# This prevents the "flat" string error
corr_matrix = df.corr(numeric_only=True)

# 3. Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Numeric Features Only)')
plt.show()

# %%
# Use numeric_only=True to exclude non-numeric columns like 'property_type'
correlation_series = df.corr(numeric_only=True)['price'].sort_values(ascending=False)

# Display the sorted correlations
print(correlation_series)
# Out:
# price                  1.000000
# price_crore            1.000000
# super_built_up_area    0.769504
# bathroom               0.589937
# bedRoom                0.523051
# servant room           0.401122
# price_per_sqft         0.391364
# pooja room             0.340992
# store room             0.309214
# study room             0.258212
# furnishing_type        0.253349
# area                   0.166432
# luxury_score           0.094871
# others                -0.003878
# carpet_area           -0.011343
# built_up_area         -0.016253
# floorNum              -0.094493
# Name: price, dtype: float64
